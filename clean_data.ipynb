# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data  = pd.read_csv("yellow_tripdata_2018-01.csv")

# %%
data.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2018-01-01 00:21:05   2018-01-01 00:24:23                1
# 1         1  2018-01-01 00:44:55   2018-01-01 01:03:05                1
# 2         1  2018-01-01 00:08:26   2018-01-01 00:14:21                2
# 3         1  2018-01-01 00:20:22   2018-01-01 00:52:51                1
# 4         1  2018-01-01 00:09:18   2018-01-01 00:27:06                2
# 5         1  2018-01-01 00:29:29   2018-01-01 00:32:48                3
# 6         1  2018-01-01 00:38:08   2018-01-01 00:48:24                2
# 7         1  2018-01-01 00:49:29   2018-01-01 00:51:53                1
# 8         1  2018-01-01 00:56:38   2018-01-01 01:01:05                1
# 9         1  2018-01-01 00:17:04   2018-01-01 00:22:24                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.5           1                  N            41            24
# 1            2.7           1                  N           239           140
# 2            0.8           1                  N           262           141
# 3           10.2           1                  N           140           257
# 4            2.5           1                  N           246           239
# 5            0.5           1                  N           143           143
# 6            1.7           1                  N            50           239
# 7            0.7           1                  N           239           238
# 8            1.0           1                  N           238            24
# 9            0.7           1                  N           170           170
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          4.5    0.5      0.5        0.00           0.0
# 1             2         14.0    0.5      0.5        0.00           0.0
# 2             1          6.0    0.5      0.5        1.00           0.0
# 3             2         33.5    0.5      0.5        0.00           0.0
# 4             1         12.5    0.5      0.5        2.75           0.0
# 5             2          4.5    0.5      0.5        0.00           0.0
# 6             1          9.0    0.5      0.5        2.05           0.0
# 7             1          4.0    0.5      0.5        1.00           0.0
# 8             1          5.5    0.5      0.5        1.70           0.0
# 9             2          5.5    0.5      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3          5.80
# 1                    0.3         15.30
# 2                    0.3          8.30
# 3                    0.3         34.80
# 4                    0.3         16.55
# 5                    0.3          5.80
# 6                    0.3         12.35
# 7                    0.3          6.30
# 8                    0.3          8.50
# 9                    0.3          6.80

# %%
#data = data[data.trip_distance > 0]
data = data.drop(data[(data.trip_distance <= 0) | (data.tpep_dropoff_datetime == data.tpep_pickup_datetime)].index)


data.count()
# Out:
# VendorID                 8704275
# tpep_pickup_datetime     8704275
# tpep_dropoff_datetime    8704275
# passenger_count          8704275
# trip_distance            8704275
# RatecodeID               8704275
# store_and_fwd_flag       8704275
# PULocationID             8704275
# DOLocationID             8704275
# payment_type             8704275
# fare_amount              8704275
# extra                    8704275
# mta_tax                  8704275
# tip_amount               8704275
# tolls_amount             8704275
# improvement_surcharge    8704275
# total_amount             8704275
# dtype: int64

# %%
8759874 - 8704275
# Out:
# 55599

# %%
pd.isnull(data).values.any()
# Out:
# False
